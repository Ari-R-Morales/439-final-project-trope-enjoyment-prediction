# %% [markdown]
# This is a notebook to extract the book data related scraped from Internet Archive

# %%
#install the internet archive library
# !pip install internetarchive
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting internetarchive
#   Downloading internetarchive-5.7.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpatch>=0.4 in /usr/lib/python3/dist-packages (from internetarchive) (1.32)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /usr/local/venv/lib/python3.12/site-packages (from internetarchive) (2.32.4)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/venv/lib/python3.12/site-packages (from internetarchive) (4.67.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/venv/lib/python3.12/site-packages (from internetarchive) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.25.0->internetarchive) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.25.0->internetarchive) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.25.0->internetarchive) (2025.8.3)
# Downloading internetarchive-5.7.1-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.6/111.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: internetarchive
#   WARNING: The script ia is installed in '/home/arm379/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed internetarchive-5.7.1

# %%
from internetarchive import search_items
import pandas as pd

query = 'mediatype:(texts) AND language:(eng)'
fields = [
    "identifier", 
    "title",
    "creator",
    "date",
    "publisher",
    "subject",
    "isbn"
]

# Ask for specific fields; params lets you control things like rows per page
search = search_items(
    query,
    fields=fields,
    params={"rows": 1000}  # you can adjust this
)

rows = []
for result in search:
    rows.append(result)

df = pd.DataFrame(rows)
df.head()
# Out:
#                   identifier                                    subject  \
# 0    abfonds2291.16-4-30bade                                       File
# 1  careerlifemanage00albe_15  [Vocational guidance, Career development]
# 2     abfonds5169-18-6bade_0                                       File
# 3      abfonds5169-8-3bade_1                                       File
# 4   designconstructi00unse_2                                        NaN
#
#                                                title  \
# 0  [A. Van Borssom - River Landscape in the Moonl...
# 1              Career and life management - Module 1
# 2                      Bredius 112 [after Rembrandt]
# 3                     [Miscellaneous Correspondence]
# 4  Design and Construction of Extra-High-Strength...
#
#                                              creator                  date  \
# 0                                                NaN                   NaN
# 1  [Alberta. Alberta Education, Alberta. Learning...  2008-01-01T00:00:00Z
# 2                                                NaN  1948-01-01T00:00:00Z
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#                                                 isbn  \
# 0                                                NaN
# 1  [9780774128742, 0774128747, 9780774128759, 077...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                       publisher
# 0                           NaN
# 1  Edmonton : Alberta Education
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
from internetarchive import search_items
import pandas as pd

# Core filters: texts + English
# Optional: subject contains 'fiction' or 'novel' to bias toward actual books
query = (
    'mediatype:(texts) AND language:(eng) '
    'AND (subject:(fiction) OR description:(novel))'
)

fields = [
    "identifier",
    "title",
    "creator",
    "date",
    "publisher",
    "subject",
    "description",
    "language",
    "collection",
    "isbn"
]

search = search_items(query, fields=fields, params={"rows": 2000})

rows = [r for r in search]
df = pd.DataFrame(rows)
df.head()
# Out:
#                                           collection  \
# 0   [internetarchivebooks, printdisabled, inlibrary]
# 1   [internetarchivebooks, inlibrary, printdisabled]
# 2  [internetarchivebooks, printdisabled, inlibrar...
# 3                            [opensource, community]
# 4   [internetarchivebooks, inlibrary, printdisabled]
#
#                           creator                  date  \
# 0                     Taylor, Max  1990-01-01T00:00:00Z
# 1  Mac a'Bháird, Natasha, author  2009-01-01T00:00:00Z
# 2           Ryan, John, 1921-2009  1991-01-01T00:00:00Z
# 3                         Myself?  2022-02-24T00:00:00Z
# 4        Freethy, Barbara, author  2016-01-01T00:00:00Z
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
#
#                         identifier  \
# 0             shortcircuit0000tayl
# 1            olannasbigday0000maca
# 2         captainpugwashhu0000ryan
# 3  goodreads_library_export_202202
# 4         lightninglingers0000free
#
#                                                 isbn language  \
# 0                        [0843127147, 9780843127140]      eng
# 1                        [9781847171719, 1847171710]      eng
# 2  [0951707108, 9780951707104, 0951707116, 978095...      eng
# 3                                                NaN      eng
# 4                        [9781628999204, 1628999209]      eng
#
#                                       publisher  \
# 0       Los Angeles, Calif. : Price Stern Sloan
# 1                    Dublin : The O'Brien Press
# 2  Rye, East Sussex [England] : Gungarden Books
# 3                                           NaN
# 4   Thorndike, Maine : Center Point Large Print
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                                title
# 0                                      Short circuit
# 1                                   Olanna's big day
# 2  Captain Pugwash and the huge reward : a tale o...
# 3                           goodreads_library_export
# 4                                  Lightning lingers

# %%
df.to_csv("ia_books_metadata.csv", index=False)

# %%
import numpy as np
import math

bad_collection_keywords = ["magazine", "periodical", "journal", "newspaper"]

def is_not_book(collection_value):
    # Handle obvious missing values
    if collection_value is None:
        return False
    if isinstance(collection_value, float) and math.isnan(collection_value):
        return False

    # Normalize to a list of strings
    if isinstance(collection_value, str):
        cols = [collection_value]
    elif isinstance(collection_value, (list, tuple, np.ndarray)):
        cols = list(collection_value)
    else:
        # Unknown type → don't flag it as non-book
        return False

    cols_lower = [str(c).lower() for c in cols if c is not None]

    # check ONLY collection labels for “magazine”, “journal”, etc.
    return any(
        bad in c
        for c in cols_lower
        for bad in bad_collection_keywords
    )

# Apply it
df["is_non_booky_collection"] = df["collection"].apply(is_not_book)
df_books_only = df[~df["is_non_booky_collection"]].copy()

# %%
df_books_only.head()
# Out:
#                                           collection  \
# 0   [internetarchivebooks, printdisabled, inlibrary]
# 1   [internetarchivebooks, inlibrary, printdisabled]
# 2  [internetarchivebooks, printdisabled, inlibrar...
# 3                            [opensource, community]
# 4   [internetarchivebooks, inlibrary, printdisabled]
#
#                           creator                  date  \
# 0                     Taylor, Max  1990-01-01T00:00:00Z
# 1  Mac a'Bháird, Natasha, author  2009-01-01T00:00:00Z
# 2           Ryan, John, 1921-2009  1991-01-01T00:00:00Z
# 3                         Myself?  2022-02-24T00:00:00Z
# 4        Freethy, Barbara, author  2016-01-01T00:00:00Z
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
#
#                         identifier  \
# 0             shortcircuit0000tayl
# 1            olannasbigday0000maca
# 2         captainpugwashhu0000ryan
# 3  goodreads_library_export_202202
# 4         lightninglingers0000free
#
#                                                 isbn language  \
# 0                        [0843127147, 9780843127140]      eng
# 1                        [9781847171719, 1847171710]      eng
# 2  [0951707108, 9780951707104, 0951707116, 978095...      eng
# 3                                                NaN      eng
# 4                        [9781628999204, 1628999209]      eng
#
#                                       publisher  \
# 0       Los Angeles, Calif. : Price Stern Sloan
# 1                    Dublin : The O'Brien Press
# 2  Rye, East Sussex [England] : Gungarden Books
# 3                                           NaN
# 4   Thorndike, Maine : Center Point Large Print
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                                title  is_non_booky_collection
# 0                                      Short circuit                    False
# 1                                   Olanna's big day                    False
# 2  Captain Pugwash and the huge reward : a tale o...                    False
# 3                           goodreads_library_export                    False
# 4                                  Lightning lingers                    False

# %%
#dataset is large so checking the values manually is encouraged to confirm that keywords are not present within the 'collection' column
df_books_only.to_csv("ia_books_only_metadata.csv", index=False)

# %% [markdown]
# Next we're going to remove unecessary columns and clean the formatting in order to preare to merge

# %%
#first, dropping irrelevant columns

# %%
cols_to_keep = ["identifier", "title", "subject", "description", "isbn"]

df_books_clean = df_books_only[cols_to_keep].copy()

#verify the columns are dropped
df_books_clean.head()
# Out:
#                         identifier  \
# 0             shortcircuit0000tayl
# 1            olannasbigday0000maca
# 2         captainpugwashhu0000ryan
# 3  goodreads_library_export_202202
# 4         lightninglingers0000free
#
#                                                title  \
# 0                                      Short circuit
# 1                                   Olanna's big day
# 2  Captain Pugwash and the huge reward : a tale o...
# 3                           goodreads_library_export
# 4                                  Lightning lingers
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
#
#                                                 isbn
# 0                        [0843127147, 9780843127140]
# 1                        [9781847171719, 1847171710]
# 2  [0951707108, 9780951707104, 0951707116, 978095...
# 3                                                NaN
# 4                        [9781628999204, 1628999209]

# %%
#second, clean the formatting for the subject column
import re
import numpy as np
import pandas as pd

import re
import numpy as np
import pandas as pd

def clean_subject(subject):
    # Gather everything as a list of strings
    if isinstance(subject, (list, tuple, np.ndarray)):
        raw_strings = [str(x) for x in subject if x is not None]
    elif subject is None or (isinstance(subject, float) and pd.isna(subject)):
        return []
    else:
        raw_strings = [str(subject)]

    # Split each string on commas/semicolons, strip outer brackets if present
    parts = []
    for s in raw_strings:
        s = s.strip()
        if s.startswith("[") and s.endswith("]"):
            s = s[1:-1]
        parts.extend(re.split(r"[;,]", s))

    # Clean each piece
    tags = []
    for piece in parts:
        t = piece.strip()
        if not t:
            continue
        t = re.sub(r"\s+", " ", t)
        tags.append(t)

    return tags

df_books_clean["subject_list"] = df_books_clean["subject"].apply(clean_subject)

# %%
def split_heading(heading: str):
    parts = [p.strip() for p in heading.split("--")]
    if not parts:
        return None, []
    form = parts[-1].lower()       # e.g. "juvenile fiction"
    topics = [p.lower() for p in parts[:-1]]  # e.g. ["crocodiles"]
    return form, topics

forms = []
topics = []
for t in df_books_clean["subject_list"].iloc[0]:  # example row
    form, tps = split_heading(t)
    if form:
        forms.append(form)
    topics.extend(tps)

# %%
df_books_clean["subject_list"].iloc[0], type(df_books_clean["subject_list"].iloc[0])
# Out:
# (['Androids -- Fiction',
#   'Science -- Exhibitions -- Fiction',
#   'Robots -- Fiction',
#   'Androids',
#   'Science -- Exhibitions'],
#  list)

# %%
#check that the tags are separated in the subject_list column
df_books_clean[["subject_list", "subject_len"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 #check that the tags are separated in the subject_list column
# ----> 2 df_books_clean[["subject_list", "subject_len"]].head(10)
#
# File /usr/local/venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File /usr/local/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['subject_len'] not in index"

# %%
# Look at a few rows side by side
df_books_clean[["subject", "subject_list"]].head(10)
# Out:
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
# 5  [Spouses -- Fiction, Husbands -- Crimes agains...
# 6  [Immigrants -- Juvenile fiction, Bullying -- J...
# 7   [Dublin (Ireland) -- Fiction, Ireland -- Dublin]
# 8  [English language -- Alphabet -- Pictorial wor...
# 9                                    English fiction
#
#                                         subject_list
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
# 5  [Spouses -- Fiction, Husbands -- Crimes agains...
# 6  [Immigrants -- Juvenile fiction, Bullying -- J...
# 7   [Dublin (Ireland) -- Fiction, Ireland -- Dublin]
# 8  [English language -- Alphabet -- Pictorial wor...
# 9                                  [English fiction]

# %%
df_books_clean.head(5)
# Out:
#                         identifier  \
# 0             shortcircuit0000tayl
# 1            olannasbigday0000maca
# 2         captainpugwashhu0000ryan
# 3  goodreads_library_export_202202
# 4         lightninglingers0000free
#
#                                                title  \
# 0                                      Short circuit
# 1                                   Olanna's big day
# 2  Captain Pugwash and the huge reward : a tale o...
# 3                           goodreads_library_export
# 4                                  Lightning lingers
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
#
#                                                 isbn  \
# 0                        [0843127147, 9780843127140]
# 1                        [9781847171719, 1847171710]
# 2  [0951707108, 9780951707104, 0951707116, 978095...
# 3                                                NaN
# 4                        [9781628999204, 1628999209]
#
#                                         subject_list
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]

# %%
import re
import numpy as np
import pandas as pd

physical_patterns = [
    r"\b\d+\s*(pages?|p\.)\b",   # "122 pages", "301 p."
    r"\bpages?\b",               # bare "pages"
    r"\bcm\b",                   # "22 cm"
    r"large print",
    r"unnumbered pages",
    r"online resource",
    r"\bvolumes?\b",
    r"\bcm\b",
]

boilerplate_patterns = [
    r"^originally published",    # "Originally published: ..."
    r"^novel$",                  # just "Novel"
    r"^ages?\s+\d",              # "Ages 5-7"
]

def looks_physical(text: str) -> bool:
    t = text.lower()
    return any(re.search(pat, t) for pat in physical_patterns)

def looks_boilerplate(text: str) -> bool:
    t = text.lower().strip()
    return any(re.search(pat, t) for pat in boilerplate_patterns)

def normalize_description(desc):
    # Handle missing
    if desc is None or (isinstance(desc, float) and pd.isna(desc)):
        return ""

    # 1) Normalize into a list of chunks
    if isinstance(desc, (list, tuple, np.ndarray)):
        chunks = [str(x).strip() for x in desc if x is not None]
    else:
        s = str(desc).strip()
        if s.startswith("[") and s.endswith("]"):
            s = s[1:-1]
        chunks = re.split(r"\s*[;,]\s*", s)

    # 2) Drop physical + boilerplate chunks
    narrative_chunks = [
        c for c in chunks
        if c
        and not looks_physical(c)
        and not looks_boilerplate(c)
    ]

    # 3) If nothing narrative left, treat as "no blurb"
    if not narrative_chunks:
        return ""

    # 4) Join narrative pieces into one blurb
    return " ".join(narrative_chunks).strip()

# Apply
df_books_clean["blurb"] = df_books_clean["description"].apply(normalize_description)

# %%
df_books_clean.loc[0:10, ["description", "blurb"]]
# Out:
#                                           description  \
# 0   [122 pages : 19 cm, Determined to raise his sc...
# 1   [32 pages : 27 cm, "There's great excitement w...
# 2                                    43 pages : 22 cm
# 3                          My library from Goodreads
# 4   [383 pages (large print) ; 23 cm, "Dr. Katheri...
# 5   [408 pages ; 24 cm, "A taut and absorbing thri...
# 6   [1 online resource, Bullied relentlessly, Hira...
# 7   [362 pages ; 24 cm, Ellie seems to have it all...
# 8       [12 unnumbered pages : 15 cm, 3+, Board book]
# 9                                                136p
# 10                                     254 p. ; 22 cm
#
#                                                 blurb
# 0   Determined to raise his science grade, Tim Wat...
# 1
# 2
# 3                           My library from Goodreads
# 4   "Dr. Katherine Barrett turns to her former hig...
# 5   "A taut and absorbing thriller about a murdere...
# 6   Bullied relentlessly, Hiram Goldfarb, a Jewish...
# 7   Ellie seems to have it all - a loving and secu...
# 8                                       3+ Board book
# 9                                                136p
# 10                                             254 p.

# %%
df_books_clean.head()
# Out:
#                         identifier  \
# 0             shortcircuit0000tayl
# 1            olannasbigday0000maca
# 2         captainpugwashhu0000ryan
# 3  goodreads_library_export_202202
# 4         lightninglingers0000free
#
#                                                title  \
# 0                                      Short circuit
# 1                                   Olanna's big day
# 2  Captain Pugwash and the huge reward : a tale o...
# 3                           goodreads_library_export
# 4                                  Lightning lingers
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
#
#                                                 isbn  \
# 0                        [0843127147, 9780843127140]
# 1                        [9781847171719, 1847171710]
# 2  [0951707108, 9780951707104, 0951707116, 978095...
# 3                                                NaN
# 4                        [9781628999204, 1628999209]
#
#                                         subject_list  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 3                               [Cookbooks, fiction]
# 4     [Large type books, Missing persons -- Fiction]
#
#                                                blurb
# 0  Determined to raise his science grade, Tim Wat...
# 1
# 2
# 3                          My library from Goodreads
# 4  "Dr. Katherine Barrett turns to her former hig...

# %%
#third, clean the formatting for the description column

#define the unecessary details/tags
physical_patterns = [
    r"\b\d+\s*(pages?|p\.)\b",   # "122 pages", "301 p."
    r"\bpages?\b",               # bare "pages"
    r"\bcm\b",                   # "22 cm"
    r"large print",
    r"unnumbered pages",
    r"online resource",
    r"\bvolumes?\b",
    r"p\.\s*\(large print\)",
]

def looks_physical(text: str) -> bool:
    t = text.lower()
    for pat in physical_patterns:
        if re.search(pat, t):
            return True
    return False

# %%
def normalize_description(desc):
    # Handle missing
    if desc is None or (isinstance(desc, float) and pd.isna(desc)):
        return ""

    # 1) Normalize into a list of chunks
    if isinstance(desc, (list, tuple, np.ndarray)):
        chunks = [str(x).strip() for x in desc if x is not None]
    else:
        s = str(desc).strip()
        # some descriptions have brackets but aren't real lists
        if s.startswith("[") and s.endswith("]"):
            s = s[1:-1]
        # split on commas or semicolons
        chunks = re.split(r"\s*[;,]\s*", s)

    # 2) Drop physical-description chunks
    narrative_chunks = [c for c in chunks if c and not looks_physical(c)]

    # 3) If nothing narrative left, fall back to original (joined)
    if not narrative_chunks:
        return " ".join(chunks).strip()

    # 4) Join narrative pieces into one blurb
    return " ".join(narrative_chunks).strip()

# Apply to your dataframe
df_books_clean["blurb"] = df_books_clean["description"].apply(normalize_description)

# %%
df_books_clean[["description", "blurb"]].head(10)
# Out:
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 3                         My library from Goodreads
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
# 5  [408 pages ; 24 cm, "A taut and absorbing thri...
# 6  [1 online resource, Bullied relentlessly, Hira...
# 7  [362 pages ; 24 cm, Ellie seems to have it all...
# 8      [12 unnumbered pages : 15 cm, 3+, Board book]
# 9                                               136p
#
#                                                blurb
# 0  Determined to raise his science grade, Tim Wat...
# 1  32 pages : 27 cm "There's great excitement whe...
# 2                                   43 pages : 22 cm
# 3                          My library from Goodreads
# 4  "Dr. Katherine Barrett turns to her former hig...
# 5  "A taut and absorbing thriller about a murdere...
# 6  Bullied relentlessly, Hiram Goldfarb, a Jewish...
# 7  Ellie seems to have it all - a loving and secu...
# 8                                      3+ Board book
# 9                                               136p

# %%
#second round cleaning of blurb column to get rid of leftover formatting
import re
import numpy as np

def clean_blurb(text):
    if pd.isna(text):
        return np.nan
    
    s = str(text).strip()
    if not s:
        return np.nan

    # normalize whitespace
    s = s.replace("\n", " ")
    s = re.sub(r"\s+", " ", s)

    # remove leading/trailing quotes
    s = re.sub(r"^['\"]+|['\"]+$", "", s)

    # 1) very short lines that are basically just page counts / size
    if len(s) < 40 and re.search(r"\bp\.|\bpages?\b|\bcm\b", s.lower()):
        return np.nan

    # 2) trim some common catalog-y tails
    s = re.sub(r"Includes bibliographical references.*$", "", s, flags=re.I)
    s = re.sub(r"--\s*back cover.*$", "", s, flags=re.I)

    s = s.strip(" ;,.-")
    return s if s else np.nan

df_books_clean["blurb"] = df_books_clean["blurb"].apply(clean_blurb)

# %%
#remove entries where isbn=NAN
import numpy as np
import pandas as pd

def remove_missing_isbn(df, col="isbn"):
    """
    Return a copy of df with rows removed where the ISBN column
    is NaN or an empty string.
    """
    # keep rows where isbn is not NaN and not just ""
    mask = df[col].notna() & (df[col].astype(str).str.strip() != "")
    return df[mask].copy()

df_books_clean = remove_missing_isbn(df_books_clean)

# %%
df_books_clean.head()
# Out:
#                  identifier  \
# 0      shortcircuit0000tayl
# 1     olannasbigday0000maca
# 2  captainpugwashhu0000ryan
# 4  lightninglingers0000free
# 5  lovinghusbandnov0000kent
#
#                                                title  \
# 0                                      Short circuit
# 1                                   Olanna's big day
# 2  Captain Pugwash and the huge reward : a tale o...
# 4                                  Lightning lingers
# 5                       The loving husband : a novel
#
#                                              subject  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 4     [Large type books, Missing persons -- Fiction]
# 5  [Spouses -- Fiction, Husbands -- Crimes agains...
#
#                                          description  \
# 0  [122 pages : 19 cm, Determined to raise his sc...
# 1  [32 pages : 27 cm, "There's great excitement w...
# 2                                   43 pages : 22 cm
# 4  [383 pages (large print) ; 23 cm, "Dr. Katheri...
# 5  [408 pages ; 24 cm, "A taut and absorbing thri...
#
#                                                 isbn  \
# 0                        [0843127147, 9780843127140]
# 1                        [9781847171719, 1847171710]
# 2  [0951707108, 9780951707104, 0951707116, 978095...
# 4                        [9781628999204, 1628999209]
# 5                        [9780374194123, 0374194122]
#
#                                         subject_list  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 4     [Large type books, Missing persons -- Fiction]
# 5  [Spouses -- Fiction, Husbands -- Crimes agains...
#
#                                                blurb
# 0  Determined to raise his science grade, Tim Wat...
# 1  32 pages : 27 cm "There's great excitement whe...
# 2                                                NaN
# 4  Dr. Katherine Barrett turns to her former high...
# 5  A taut and absorbing thriller about a murdered...

# %%
#fourth, choose a prinary isbn
import re
import pandas as pd

def normalize_isbn(isbn):
    if pd.isna(isbn):
        return pd.NA
    s = str(isbn)
    # remove anything that's not a digit or X (for ISBN-10)
    s = re.sub(r"[^0-9Xx]", "", s)
    s = s.upper()
    return s or pd.NA

def make_isbn_list(cell):
    """
    Take a raw isbn cell (possibly:
      - a Python list like [0843..., 9780...]
      - or a string like "0843..., 9780..."
      - or NaN),
    and return a list of normalized ISBN strings (10 or 13 digits).
    """
    # case 1: already a list from your dataframe
    if isinstance(cell, list):
        parts = cell

    # case 2: missing
    elif pd.isna(cell):
        return []

    # case 3: a string / other scalar
    else:
        parts = str(cell).split(",")

    out = []
    for p in parts:
        nx = normalize_isbn(p)
        if pd.notna(nx):
            out.append(nx)
    return out


def choose_primary_isbn(isbn_list):
    """
    Prefer an ISBN-13 if present, otherwise fall back to the first one.
    """
    if not isbn_list:
        return pd.NA
    # 1) prefer 13-digit ISBNs
    for s in isbn_list:
        if len(s) == 13:
            return s
    # 2) if no 13-digit, just use the first one (likely ISBN-10)
    return isbn_list[0]

# apply to your dataframe
df_blurbs = df_books_clean.copy()

df_blurbs["isbn_list"] = df_blurbs["isbn"].apply(make_isbn_list)
df_blurbs["primary_isbn"] = df_blurbs["isbn_list"].apply(choose_primary_isbn)

# %%
#confirm formatting
df_blurbs[["primary_isbn", "title", "blurb", "subject_list"]].head(10)
# Out:
#      primary_isbn                                              title  \
# 0   9780843127140                                      Short circuit
# 1   9781847171719                                   Olanna's big day
# 2   9780951707104  Captain Pugwash and the huge reward : a tale o...
# 4   9781628999204                                  Lightning lingers
# 5   9780374194123                       The loving husband : a novel
# 6   9781467724128                                    Lightning's run
# 7   9781444743661                                         The letter
# 8   9781849589604                                            Letters
# 9      0950620114                         Journal of a coffin dodger
# 10     1590580230                               The laughing hangman
#
#                                                 blurb  \
# 0   Determined to raise his science grade, Tim Wat...
# 1   32 pages : 27 cm "There's great excitement whe...
# 2                                                 NaN
# 4   Dr. Katherine Barrett turns to her former high...
# 5   A taut and absorbing thriller about a murdered...
# 6   Bullied relentlessly, Hiram Goldfarb, a Jewish...
# 7   Ellie seems to have it all - a loving and secu...
# 8                                       3+ Board book
# 9                                                136p
# 10                                                NaN
#
#                                          subject_list
# 0   [Androids -- Fiction, Science -- Exhibitions -...
# 1   [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2   [Pugwash, Captain (Fictitious character) -- Ju...
# 4      [Large type books, Missing persons -- Fiction]
# 5   [Spouses -- Fiction, Husbands -- Crimes agains...
# 6   [Immigrants -- Juvenile fiction, Bullying -- J...
# 7    [Dublin (Ireland) -- Fiction, Ireland -- Dublin]
# 8   [English language -- Alphabet -- Pictorial wor...
# 9                                   [English fiction]
# 10  [Bracewell, Nicholas (Fictitious character) --...

# %%
#create the sheet of the final cleaned dataset
cols_to_keep = ["primary_isbn", "title", "subject_list", "blurb"]
df_books_final = df_blurbs[cols_to_keep].copy()
df_books_final.head()
# Out:
#     primary_isbn                                              title  \
# 0  9780843127140                                      Short circuit
# 1  9781847171719                                   Olanna's big day
# 2  9780951707104  Captain Pugwash and the huge reward : a tale o...
# 4  9781628999204                                  Lightning lingers
# 5  9780374194123                       The loving husband : a novel
#
#                                         subject_list  \
# 0  [Androids -- Fiction, Science -- Exhibitions -...
# 1  [Nigerians -- Ireland -- Juvenile fiction, Sai...
# 2  [Pugwash, Captain (Fictitious character) -- Ju...
# 4     [Large type books, Missing persons -- Fiction]
# 5  [Spouses -- Fiction, Husbands -- Crimes agains...
#
#                                                blurb
# 0  Determined to raise his science grade, Tim Wat...
# 1  32 pages : 27 cm "There's great excitement whe...
# 2                                                NaN
# 4  Dr. Katherine Barrett turns to her former high...
# 5  A taut and absorbing thriller about a murdered...

# %%
df_books_final.to_csv("ia_clean_dataset.csv", index=False)
